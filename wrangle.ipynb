# %%
import numpy as np
import pandas as pd
import scipy.stats as stats

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.dummy import DummyClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.inspection import permutation_importance
from sklearn.tree import export_graphviz

# %% [markdown]
# # Acquire

# %%
df = pd.read_csv('Austin Bicycle Crashes 2010-2017.csv')

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#    Crash ID $1000 Damage to Any One Person's Property Active School Zone Flag  \
# 0  11243623                                        No                      No
# 1  12112069                                        No                      No
# 2  12112069                                        No                      No
# 3  12112069                                        No                      No
# 4  11376123                                        No                      No
#
#   Adjusted Average Daily Traffic Amount                    Agency  \
# 0                                 15262  Austin Police Department
# 1                               No Data  Austin Police Department
# 2                               No Data  Austin Police Department
# 3                               No Data  Austin Police Department
# 4                                 22775  Austin Police Department
#
#    At Intersection Flag Average Daily Traffic Amount  \
# 0                 False                        15262
# 1                 False                      No Data
# 2                 False                      No Data
# 3                 False                      No Data
# 4                 False                        22775
#
#   Average Daily Traffic Year    Case ID    City Construction Zone Flag  \
# 0                       2014  100010723  Austin                     No
# 1                    No Data  100010834  Austin                     No
# 2                    No Data  100010834  Austin                     No
# 3                    No Data  100010834  Austin                     No
# 4                       2014  100042009  Austin                     No
#
#   Construction Zone Workers Present Flag  County  Crash Death Count  \
# 0                                     No  Travis                  0
# 1                                     No  Travis                  0
# 2                                     No  Travis                  0
# 3                                     No  Travis                  0
# 4                                     No  Travis                  0
#
#    Crash Incapacitating Injury Count  Crash Non-incapacitating Injury Count  \
# 0                                  1                                      0
# 1                                  0                                      2
# 2                                  0                                      2
# 3                                  0                                      2
# 4                                  0                                      1
#
#    Crash Not Injured Count  Crash Possible Injury Count  \
# 0                        0                            0
# 1                        1                            0
# 2                        1                            0
# 3                        1                            0
# 4                        1                            0
#
#               Crash Severity  Crash Time  Crash Total Injury Count  \
# 0      Incapacitating Injury         239                         1
# 1  Non-Incapacitating Injury         310                         2
# 2  Non-Incapacitating Injury         310                         2
# 3  Non-Incapacitating Injury         310                         2
# 4  Non-Incapacitating Injury        2300                         1
#
#    Crash Unknown Injury Count  Crash Year Day of Week First Harmful Event  \
# 0                           1        2010      Friday        Pedalcyclist
# 1                           1        2010      Friday        Pedalcyclist
# 2                           1        2010      Friday        Pedalcyclist
# 3                           1        2010      Friday        Pedalcyclist
# 4                           0        2010      Monday        Pedalcyclist
#
#    Highway System Intersecting Street Name  Intersection Related     Latitude  \
# 0  Farm To Market                      NaN      Non Intersection  30.28608823
# 1         No Data                      NaN      Non Intersection  30.25524478
# 2         No Data                      NaN      Non Intersection  30.25524478
# 3         No Data                      NaN      Non Intersection  30.25524478
# 4      State Loop                E 16TH ST  Intersection Related  30.27959299
#
#      Light Condition     Longitude                 Manner of Collision  \
# 0      Dark, Lighted   -97.6805777  One Motor Vehicle - Going Straight
# 1      Dark, Lighted  -97.74505246  One Motor Vehicle - Going Straight
# 2      Dark, Lighted  -97.74505246  One Motor Vehicle - Going Straight
# 3      Dark, Lighted  -97.74505246  One Motor Vehicle - Going Straight
# 4  Dark, Not Lighted  -97.70207457  One Motor Vehicle - Going Straight
#
#   Number of Lanes    Other Factor Outside Shoulder Width on Divided Highway  \
# 0               4  Not Applicable                                         0
# 1         No Data  Not Applicable                                   No Data
# 2         No Data  Not Applicable                                   No Data
# 3         No Data  Not Applicable                                   No Data
# 4               4  Not Applicable                                         2
#
#   Physical Feature 1      Population Group Private Drive Flag  \
# 0     Not Applicable  250,000 Pop And Over                 No
# 1     Not Applicable  250,000 Pop And Over                 No
# 2     Not Applicable  250,000 Pop And Over                 No
# 3     Not Applicable  250,000 Pop And Over                 No
# 4     Not Applicable  250,000 Pop And Over                 No
#
#   Property Damages Right of Way Usual Width           Road Class  \
# 0             NONE                      100       Farm To Market
# 1             NONE                  No Data          City Street
# 2             NONE                  No Data          City Street
# 3             NONE                  No Data          City Street
# 4             NONE                      160  US & State Highways
#
#      Roadway Alignment      Roadway Part Roadway Relation  \
# 0  Straight, Hillcrest  Main/Proper Lane       On Roadway
# 1      Straight, Level  Main/Proper Lane       On Roadway
# 2      Straight, Level  Main/Proper Lane       On Roadway
# 3      Straight, Level  Main/Proper Lane       On Roadway
# 4      Straight, Level  Main/Proper Lane       On Roadway
#
#                  Roadway Type  Speed Limit     Street Name Street Number  \
# 0  4 Or More Lanes, Undivided           45          FM0969          4716
# 1                     No Data           35  E RIVERSIDE DR           200
# 2                     No Data           35  E RIVERSIDE DR           200
# 3                     No Data           35  E RIVERSIDE DR           200
# 4  4 Or More Lanes, Undivided           45          SL0111          1487
#
#   Surface Condition   Traffic Control Type Weather Condition  Person Helmet  \
# 0               Dry           Marked Lanes             Clear  Worn, Damaged
# 1               Dry  Center Stripe/Divider             Clear       Not Worn
# 2               Dry  Center Stripe/Divider             Clear       Not Worn
# 3               Dry  Center Stripe/Divider             Clear       Not Worn
# 4               Dry                   None             Clear       Not Worn
#
#     Person Type
# 0  Pedalcyclist
# 1  Pedalcyclist
# 2  Pedalcyclist
# 3  Pedalcyclist
# 4  Pedalcyclist

# %%
df.size, \
df.shape
# Out:
# (130751, (2467, 53))

# %%
df.describe().T
# Out:
#                                         count          mean           std  \
# Crash ID                               2467.0  1.363072e+07  1.362193e+06
# Crash Death Count                      2467.0  6.485610e-03  8.028798e-02
# Crash Incapacitating Injury Count      2467.0  1.917308e-01  1.161059e+00
# Crash Non-incapacitating Injury Count  2467.0  6.364005e-01  5.648717e-01
# Crash Not Injured Count                2467.0  1.208350e+00  9.317566e-01
# Crash Possible Injury Count            2467.0  2.622619e-01  4.863575e-01
# Crash Time                             2467.0  1.405577e+03  5.589722e+02
# Crash Total Injury Count               2467.0  1.090393e+00  1.208050e+00
# Crash Unknown Injury Count             2467.0  1.588974e-01  4.164657e-01
# Crash Year                             2467.0  2.013407e+03  2.249557e+00
# Speed Limit                            2467.0  2.639157e+01  1.700970e+01
#
#                                               min         25%         50%  \
# Crash ID                               11167757.0  12470025.0  13537694.0
# Crash Death Count                             0.0         0.0         0.0
# Crash Incapacitating Injury Count             0.0         0.0         0.0
# Crash Non-incapacitating Injury Count         0.0         0.0         1.0
# Crash Not Injured Count                       0.0         1.0         1.0
# Crash Possible Injury Count                   0.0         0.0         0.0
# Crash Time                                    1.0      1008.0      1533.0
# Crash Total Injury Count                      0.0         1.0         1.0
# Crash Unknown Injury Count                    0.0         0.0         0.0
# Crash Year                                 2010.0      2011.0      2013.0
# Speed Limit                                  -1.0         0.0        30.0
#
#                                               75%         max
# Crash ID                               14735840.5  16142780.0
# Crash Death Count                             0.0         1.0
# Crash Incapacitating Injury Count             0.0        14.0
# Crash Non-incapacitating Injury Count         1.0         4.0
# Crash Not Injured Count                       1.0         9.0
# Crash Possible Injury Count                   0.0         5.0
# Crash Time                                 1823.0      2358.0
# Crash Total Injury Count                      1.0        15.0
# Crash Unknown Injury Count                    0.0         4.0
# Crash Year                                 2015.0      2017.0
# Speed Limit                                  35.0        65.0

# %%
def df_info(df):
    print(df.info())
    print()
    print(df.size, df.shape)
    print()
    print(df.isnull().sum())
    print()
    for col in df.columns:
        print(col)
        print('Unique values:', df[col].nunique())
        print()
        print('Datatype:', df[col].dtype)
        print()
        print(df[col].value_counts())
        print('|--------------------|')
        print('|--------------------|')
        print('|--------------------|')
    return df.describe().T

# %%
df_info(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2467 entries, 0 to 2466
# Data columns (total 53 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Crash ID                                   2467 non-null   int64
#  1   $1000 Damage to Any One Person's Property  2467 non-null   object
#  2   Active School Zone Flag                    2467 non-null   object
#  3   Adjusted Average Daily Traffic Amount      2467 non-null   object
#  4   Agency                                     2467 non-null   object
#  5   At Intersection Flag                       2467 non-null   bool
#  6   Average Daily Traffic Amount               2467 non-null   object
#  7   Average Daily Traffic Year                 2467 non-null   object
#  8   Case ID                                    2432 non-null   object
#  9   City                                       2467 non-null   object
#  10  Construction Zone Flag                     2467 non-null   object
#  11  Construction Zone Workers Present Flag     2467 non-null   object
#  12  County                                     2467 non-null   object
#  13  Crash Death Count                          2467 non-null   int64
#  14  Crash Incapacitating Injury Count          2467 non-null   int64
#  15  Crash Non-incapacitating Injury Count      2467 non-null   int64
#  16  Crash Not Injured Count                    2467 non-null   int64
#  17  Crash Possible Injury Count                2467 non-null   int64
#  18  Crash Severity                             2467 non-null   object
#  19  Crash Time                                 2467 non-null   int64
#  20  Crash Total Injury Count                   2467 non-null   int64
#  21  Crash Unknown Injury Count                 2467 non-null   int64
#  22  Crash Year                                 2467 non-null   int64
#  23  Day of Week                                2467 non-null   object
#  24  First Harmful Event                        2467 non-null   object
#  25  Highway System                             2467 non-null   object
#  26  Intersecting Street Name                   1469 non-null   object
#  27  Intersection Related                       2467 non-null   object
#  28  Latitude                                   2467 non-null   object
#  29  Light Condition                            2467 non-null   object
#  30  Longitude                                  2467 non-null   object
#  31  Manner of Collision                        2467 non-null   object
#  32  Number of Lanes                            2467 non-null   object
#  33  Other Factor                               2467 non-null   object
#  34  Outside Shoulder Width on Divided Highway  2467 non-null   object
#  35  Physical Feature 1                         2467 non-null   object
#  36  Population Group                           2467 non-null   object
#  37  Private Drive Flag                         2467 non-null   object
#  38  Property Damages                           2467 non-null   object
#  39  Right of Way Usual Width                   2467 non-null   object
#  40  Road Class                                 2467 non-null   object
#  41  Roadway Alignment                          2467 non-null   object
#  42  Roadway Part                               2467 non-null   object
#  43  Roadway Relation                           2467 non-null   object
#  44  Roadway Type                               2467 non-null   object
#  45  Speed Limit                                2467 non-null   int64
#  46  Street Name                                2467 non-null   object
#  47  Street Number                              2467 non-null   object
#  48  Surface Condition                          2467 non-null   object
#  49  Traffic Control Type                       2467 non-null   object
#  50  Weather Condition                          2467 non-null   object
#  51  Person Helmet                              2467 non-null   object
#  52  Person Type                                2467 non-null   object
# dtypes: bool(1), int64(11), object(41)
# memory usage: 1004.8+ KB
# None
#
# 130751 (2467, 53)
#
# Crash ID                                       0
# $1000 Damage to Any One Person's Property      0
# Active School Zone Flag                        0
# Adjusted Average Daily Traffic Amount          0
# Agency                                         0
# At Intersection Flag                           0
# Average Daily Traffic Amount                   0
# Average Daily Traffic Year                     0
# Case ID                                       35
# City                                           0
# Construction Zone Flag                         0
# Construction Zone Workers Present Flag         0
# County                                         0
# Crash Death Count                              0
# Crash Incapacitating Injury Count              0
# Crash Non-incapacitating Injury Count          0
# Crash Not Injured Count                        0
# Crash Possible Injury Count                    0
# Crash Severity                                 0
# Crash Time                                     0
# Crash Total Injury Count                       0
# Crash Unknown Injury Count                     0
# Crash Year                                     0
# Day of Week                                    0
# First Harmful Event                            0
# Highway System                                 0
# Intersecting Street Name                     998
# Intersection Related                           0
# Latitude                                       0
# Light Condition                                0
# Longitude                                      0
# Manner of Collision                            0
# Number of Lanes                                0
# Other Factor                                   0
# Outside Shoulder Width on Divided Highway      0
# Physical Feature 1                             0
# Population Group                               0
# Private Drive Flag                             0
# Property Damages                               0
# Right of Way Usual Width                       0
# Road Class                                     0
# Roadway Alignment                              0
# Roadway Part                                   0
# Roadway Relation                               0
# Roadway Type                                   0
# Speed Limit                                    0
# Street Name                                    0
# Street Number                                  0
# Surface Condition                              0
# Traffic Control Type                           0
# Weather Condition                              0
# Person Helmet                                  0
# Person Type                                    0
# dtype: int64
#
# Crash ID
# Unique values: 2374
#
# Datatype: int64
#
# 12470025    16
# 12919603     4
# 12195628     4
# 12077374     4
# 13079200     4
#             ..
# 13061976     1
# 12011562     1
# 11983486     1
# 15948412     1
# 14012416     1
# Name: Crash ID, Length: 2374, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# $1000 Damage to Any One Person's Property
# Unique values: 2
#
# Datatype: object
#
# No     1738
# Yes     729
# Name: $1000 Damage to Any One Person's Property, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Active School Zone Flag
# Unique values: 2
#
# Datatype: object
#
# No     2464
# Yes       3
# Name: Active School Zone Flag, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Adjusted Average Daily Traffic Amount
# Unique values: 79
#
# Datatype: object
#
# No Data    2143
# 34215        29
# 33647        26
# 148494       21
# 44866        12
#            ...
# 56417         1
# 139928        1
# 35009         1
# 27085         1
# 34328         1
# Name: Adjusted Average Daily Traffic Amount, Length: 79, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Agency
# Unique values: 7
#
# Datatype: object
#
# Austin Police Department                           2441
# Department Of Public Safety, State Of Texas          20
# University Of Texas At Austin Police Department       2
# Travis County Sheriff's Office                        1
# Sunset Valley Police Department                       1
# Austin ISD Police Department                          1
# St Edward's University Police Department              1
# Name: Agency, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# At Intersection Flag
# Unique values: 2
#
# Datatype: bool
#
# True     1297
# False    1170
# Name: At Intersection Flag, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Average Daily Traffic Amount
# Unique values: 81
#
# Datatype: object
#
# No Data    2114
# 34215        31
# 33647        29
# 148494       24
# 44866        13
#            ...
# 139928        1
# 56417         1
# 69369         1
# 35009         1
# 18049         1
# Name: Average Daily Traffic Amount, Length: 81, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Average Daily Traffic Year
# Unique values: 2
#
# Datatype: object
#
# No Data    2143
# 2014        324
# Name: Average Daily Traffic Year, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Case ID
# Unique values: 2335
#
# Datatype: object
#
# 113551522     16
# 130010763      4
# 12-1680267     4
# 171610442      4
# 140610313      4
#               ..
# 110621165      1
# 11-0631322     1
# 140351124      1
# 150300575      1
# 12-0960145     1
# Name: Case ID, Length: 2335, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# City
# Unique values: 1
#
# Datatype: object
#
# Austin    2467
# Name: City, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Construction Zone Flag
# Unique values: 2
#
# Datatype: object
#
# No     2437
# Yes      30
# Name: Construction Zone Flag, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Construction Zone Workers Present Flag
# Unique values: 2
#
# Datatype: object
#
# No     2457
# Yes      10
# Name: Construction Zone Workers Present Flag, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# County
# Unique values: 1
#
# Datatype: object
#
# Travis    2467
# Name: County, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Crash Death Count
# Unique values: 2
#
# Datatype: int64
#
# 0    2451
# 1      16
# Name: Crash Death Count, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Crash Incapacitating Injury Count
# Unique values: 5
#
# Datatype: int64
#
# 0     2213
# 1      231
# 14      16
# 3        4
# 2        3
# Name: Crash Incapacitating Injury Count, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Crash Non-incapacitating Injury Count
# Unique values: 5
#
# Datatype: int64
#
# 1    1419
# 0     982
# 2      51
# 3      11
# 4       4
# Name: Crash Non-incapacitating Injury Count, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Crash Not Injured Count
# Unique values: 9
#
# Datatype: int64
#
# 1    1599
# 2     349
# 0     335
# 3     107
# 4      40
# 5      27
# 7       5
# 6       4
# 9       1
# Name: Crash Not Injured Count, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Crash Possible Injury Count
# Unique values: 5
#
# Datatype: int64
#
# 0    1860
# 1     577
# 2      22
# 3       7
# 5       1
# Name: Crash Possible Injury Count, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Crash Severity
# Unique values: 6
#
# Datatype: object
#
# Non-Incapacitating Injury    1474
# Possible Injury               556
# Incapacitating Injury         254
# Not Injured                   163
# Killed                         16
# Unknown                         4
# Name: Crash Severity, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Crash Time
# Unique values: 992
#
# Datatype: int64
#
# 1830    22
# 1800    11
# 1900    10
# 1749    10
# 1756    10
#         ..
# 859      1
# 1352     1
# 847      1
# 1356     1
# 2049     1
# Name: Crash Time, Length: 992, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Crash Total Injury Count
# Unique values: 7
#
# Datatype: int64
#
# 1     2139
# 0      180
# 2       97
# 3       25
# 15      16
# 4        9
# 6        1
# Name: Crash Total Injury Count, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Crash Unknown Injury Count
# Unique values: 5
#
# Datatype: int64
#
# 0    2110
# 1     333
# 2      16
# 3       5
# 4       3
# Name: Crash Unknown Injury Count, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Crash Year
# Unique values: 8
#
# Datatype: int64
#
# 2011    381
# 2012    336
# 2013    328
# 2014    315
# 2017    297
# 2016    283
# 2015    266
# 2010    261
# Name: Crash Year, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Day of Week
# Unique values: 7
#
# Datatype: object
#
# Friday       436
# Wednesday    387
# Tuesday      386
# Thursday     363
# Saturday     316
# Monday       305
# Sunday       274
# Name: Day of Week, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# First Harmful Event
# Unique values: 5
#
# Datatype: object
#
# Pedalcyclist                  2447
# Motor Vehicle In Transport      15
# Parked Car                       3
# Overturned                       1
# Other Object                     1
# Name: First Harmful Event, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Highway System
# Unique values: 8
#
# Datatype: object
#
# No Data           2083
# State Loop         161
# Interstate          90
# US Highway          53
# Farm To Market      42
# Ranch To Mkt        19
# State Highway       15
# State Spur           4
# Name: Highway System, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Intersecting Street Name
# Unique values: 545
#
# Datatype: object
#
# UNKNOWN              200
# GUADALUPE ST          28
# E RIVERSIDE DR        19
# IH0035                18
# E 6TH ST              15
#                     ...
# EMERALD FOREST DR      1
# W NORTH LOOP BLVD      1
# W ALPINE RD            1
# COLLIER ST             1
# RICHARDINE AVE         1
# Name: Intersecting Street Name, Length: 545, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Intersection Related
# Unique values: 5
#
# Datatype: object
#
# Intersection            871
# Non Intersection        626
# Intersection Related    590
# Driveway Access         379
# Not Reported              1
# Name: Intersection Related, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Latitude
# Unique values: 1718
#
# Datatype: object
#
# No Data        250
# 30.27406572     16
# 30.26339563     11
# 30.30274477      9
# 30.22964479      8
#               ...
# 30.29461477      1
# 30.1796148       1
# 30.42381144      1
# 30.36298476      1
# 30.27595417      1
# Name: Latitude, Length: 1718, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Light Condition
# Unique values: 7
#
# Datatype: object
#
# Daylight                  1717
# Dark, Lighted              538
# Dark, Not Lighted          112
# Dusk                        41
# Dark, Unknown Lighting      27
# Dawn                        17
# Unknown                     15
# Name: Light Condition, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Longitude
# Unique values: 1719
#
# Datatype: object
#
# No Data         250
# -97.76065126     16
# -97.74449683     11
# -97.73815246     10
# -97.76025246      8
#                ...
# -97.74305246      1
# -97.74910943      1
# -97.72928997      1
# -97.77267992      1
# -97.69734247      1
# Name: Longitude, Length: 1719, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Manner of Collision
# Unique values: 10
#
# Datatype: object
#
# One Motor Vehicle - Going Straight                 1401
# One Motor Vehicle - Turning Left                    572
# One Motor Vehicle - Turning Right                   440
# One Motor Vehicle - Backing                          28
# One Motor Vehicle - Other                            11
# Angle - Both Going Straight                           6
# Opposite Direction - One Straight-One Left Turn       4
# Same Direction - Both Going Straight-Rear End         3
# Opposite Direction - Both Going Straight              1
# Same Direction - One Straight-One Stopped             1
# Name: Manner of Collision, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Number of Lanes
# Unique values: 7
#
# Datatype: object
#
# No Data    2114
# 4           181
# 6           127
# 8            27
# 5            10
# 7             5
# 2             3
# Name: Number of Lanes, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Other Factor
# Unique values: 28
#
# Datatype: object
#
# Not Applicable                                                                 1530
# Attention Diverted From Driving                                                 351
# One Vehicle Leaving Driveway                                                    236
# One Vehicle Entering Driveway                                                   193
# Construction - Within Posted Road Construction Zone (Not Related To Crash)       28
# Slowing/Stopping-For Traffic                                                     20
# Vehicle Changing Lanes                                                           17
# Vision Obstructed By Headlight Or Sun Glare                                      16
# One Vehicle Backward From Parking                                                 8
# Slowing/Stopping - For Officer, Flagman, Or Traffic Control                       8
# Vision Obstructed By Other Visual Obstructions                                    7
# Open Door Or Object Projecting From Vehicle                                       7
# Swerved Or Veered-Reason Not Specified                                            6
# Vehicle Passing Or Attempting To Pass On Left                                     6
# One Vehicle Forward From Parking                                                  4
# Lost Control Or Skidded (Icy Or Slick Road, etc.)                                 4
# Slowing/Stopping-To Make Right Turn                                               4
# Vision Obstructed By Standing Or Parked Vehicle                                   3
# Swerved Or Veered-Avoiding Vehicle Stopped Or Moving Slowly In Traffic Lane       3
# Slowing/Stopping-For Pedestrian, Pedalcyclist, etc. In Road                       3
# Slowing/Stopping-Reason Not Specified                                             3
# Vision Obstructed By Moving Vehicle                                               2
# Slowing/Stopping-To Make Left Turn                                                2
# Vision Obstructed By Trees, Shrubs, Weeds, etc.                                   2
# Swerved Or Veered-Avoiding Pedestrian, Pedalcyclist, etc. In Road                 1
# Swerved Or Veered-Avoiding Vehicle Entering Road                                  1
# Construction-Within Posted Road Construction Zone (Related To Crash)              1
# Vehicle Passing Or Attempting To Pass On Right                                    1
# Name: Other Factor, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Outside Shoulder Width on Divided Highway
# Unique values: 11
#
# Datatype: object
#
# No Data    2114
# 10          172
# 0           104
# 5            26
# 8            13
# 2            13
# 6            10
# 7             7
# 12            5
# 4             2
# 1             1
# Name: Outside Shoulder Width on Divided Highway, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Physical Feature 1
# Unique values: 8
#
# Datatype: object
#
# Not Applicable                                           1916
# Entrance To Or Exit From Private Property Or Driveway     355
# In A Parking Lot                                          104
# Private Drive Or Road                                      62
# Parking Area Within Right Of Way                           13
# Alley                                                      12
# One Or More Traffic Lanes Closed                            4
# RR Grade Crossing                                           1
# Name: Physical Feature 1, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Population Group
# Unique values: 1
#
# Datatype: object
#
# 250,000 Pop And Over    2467
# Name: Population Group, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Private Drive Flag
# Unique values: 2
#
# Datatype: object
#
# No     2353
# Yes     114
# Name: Private Drive Flag, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Property Damages
# Unique values: 84
#
# Datatype: object
#
# NONE                                        1993
# No Data                                      315
# BICYCLE                                       69
# BLUE BICYCLE                                   3
# TREK BICYCLE                                   3
#                                             ...
# POSSIBLE TO BIKE                               1
# PEDI CAB                                       1
# CABEROLE SALSA 12 SPEED BICYCLE (1500.00       1
# BYCICLE                                        1
# BLUE SE LAGER BICYCLE                          1
# Name: Property Damages, Length: 84, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Right of Way Usual Width
# Unique values: 23
#
# Datatype: object
#
# No Data    2114
# 300          81
# 80           74
# 100          28
# 120          26
# 260          18
# 350          16
# 160          16
# 200          16
# 380          14
# 125          14
# 291          10
# 150           8
# 70            7
# 74            7
# 310           4
# 190           3
# 320           2
# 480           2
# 400           2
# 500           2
# 610           2
# 290           1
# Name: Right of Way Usual Width, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Road Class
# Unique values: 7
#
# Datatype: object
#
# City Street            1844
# US & State Highways     260
# Non Trafficway          180
# Interstate               96
# Farm To Market           71
# County Road              15
# Other Roads               1
# Name: Road Class, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Roadway Alignment
# Unique values: 8
#
# Datatype: object
#
# Straight, Level                 1861
# Straight, Grade                  354
# Straight, Hillcrest               87
# Curve, Grade                      63
# Curve, Level                      47
# Unknown                           30
# Other (Explain In Narrative)      16
# Curve, Hillcrest                   9
# Name: Roadway Alignment, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Roadway Part
# Unique values: 4
#
# Datatype: object
#
# Main/Proper Lane                2148
# Service/Frontage Road            159
# Other (Explain In Narrative)     153
# Entrance/On Ramp                   7
# Name: Roadway Part, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Roadway Relation
# Unique values: 5
#
# Datatype: object
#
# On Roadway        2206
# Not Applicable     176
# Off Roadway         71
# Shoulder            13
# Not Reported         1
# Name: Roadway Relation, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Roadway Type
# Unique values: 5
#
# Datatype: object
#
# No Data                       2114
# 4 Or More Lanes, Divided       201
# 4 Or More Lanes, Undivided     149
# Other Road Type                  2
# 2 Lane, 2 Way                    1
# Name: Roadway Type, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Speed Limit
# Unique values: 17
#
# Datatype: int64
#
#  35    691
#  30    578
# -1     345
#  0     279
#  45    190
#  40    185
#  55     55
#  25     50
#  50     38
#  60     15
#  5       9
#  10      9
#  15      7
#  20      7
#  65      7
#  36      1
#  32      1
# Name: Speed Limit, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Street Name
# Unique values: 591
#
# Datatype: object
#
# GUADALUPE ST                 118
# SL0343                        96
# IH0035                        90
# CONGRESS AVE S                67
# S CONGRESS AVE                57
#                             ...
# JAMES HALLER DR                1
# S S PLEASANT VALLEY RD RD      1
# TAYLORCREST DR                 1
# ETON LN                        1
# FALL MEADOW LN                 1
# Name: Street Name, Length: 591, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Street Number
# Unique values: 930
#
# Datatype: object
#
# NO DATA    744
# 100         35
# 600         23
# 200         18
# 1407        16
#           ...
# 7924         1
# 8360         1
# 2629         1
# 2837         1
# 4577         1
# Name: Street Number, Length: 930, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Surface Condition
# Unique values: 7
#
# Datatype: object
#
# Dry                             2298
# Wet                              151
# Unknown                           13
# Other (Explain In Narrative)       2
# Ice                                1
# Sand, Mud, Dirt                    1
# Standing Water                     1
# Name: Surface Condition, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Traffic Control Type
# Unique values: 16
#
# Datatype: object
#
# Signal Light                                  624
# None                                          600
# Marked Lanes                                  420
# Stop Sign                                     391
# Bike Lane                                     151
# Center Stripe/Divider                         115
# Crosswalk                                      57
# Other (Explain In Narrative)                   31
# Yield Sign                                     29
# Signal Light With Red Light Running Camera     26
# Flashing Red Light                             12
# Officer                                         3
# No Passing Zone                                 3
# Warning Sign                                    3
# Flashing Yellow Light                           1
# Flagman                                         1
# Name: Traffic Control Type, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Weather Condition
# Unique values: 7
#
# Datatype: object
#
# Clear                           2061
# Cloudy                           272
# Rain                             110
# Unknown                           18
# Fog                                3
# Other (Explain In Narrative)       2
# Blowing Sand/Snow                  1
# Name: Weather Condition, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Person Helmet
# Unique values: 5
#
# Datatype: object
#
# Not Worn             1356
# Unknown If Worn       450
# Worn, Not Damaged     341
# Worn, Unk Damage      171
# Worn, Damaged         149
# Name: Person Helmet, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
# Person Type
# Unique values: 1
#
# Datatype: object
#
# Pedalcyclist    2467
# Name: Person Type, dtype: int64
# |--------------------|
# |--------------------|
# |--------------------|
#                                         count          mean           std  \
# Crash ID                               2467.0  1.363072e+07  1.362193e+06
# Crash Death Count                      2467.0  6.485610e-03  8.028798e-02
# Crash Incapacitating Injury Count      2467.0  1.917308e-01  1.161059e+00
# Crash Non-incapacitating Injury Count  2467.0  6.364005e-01  5.648717e-01
# Crash Not Injured Count                2467.0  1.208350e+00  9.317566e-01
# Crash Possible Injury Count            2467.0  2.622619e-01  4.863575e-01
# Crash Time                             2467.0  1.405577e+03  5.589722e+02
# Crash Total Injury Count               2467.0  1.090393e+00  1.208050e+00
# Crash Unknown Injury Count             2467.0  1.588974e-01  4.164657e-01
# Crash Year                             2467.0  2.013407e+03  2.249557e+00
# Speed Limit                            2467.0  2.639157e+01  1.700970e+01
#
#                                               min         25%         50%  \
# Crash ID                               11167757.0  12470025.0  13537694.0
# Crash Death Count                             0.0         0.0         0.0
# Crash Incapacitating Injury Count             0.0         0.0         0.0
# Crash Non-incapacitating Injury Count         0.0         0.0         1.0
# Crash Not Injured Count                       0.0         1.0         1.0
# Crash Possible Injury Count                   0.0         0.0         0.0
# Crash Time                                    1.0      1008.0      1533.0
# Crash Total Injury Count                      0.0         1.0         1.0
# Crash Unknown Injury Count                    0.0         0.0         0.0
# Crash Year                                 2010.0      2011.0      2013.0
# Speed Limit                                  -1.0         0.0        30.0
#
#                                               75%         max
# Crash ID                               14735840.5  16142780.0
# Crash Death Count                             0.0         1.0
# Crash Incapacitating Injury Count             0.0        14.0
# Crash Non-incapacitating Injury Count         1.0         4.0
# Crash Not Injured Count                       1.0         9.0
# Crash Possible Injury Count                   0.0         5.0
# Crash Time                                 1823.0      2358.0
# Crash Total Injury Count                      1.0        15.0
# Crash Unknown Injury Count                    0.0         4.0
# Crash Year                                 2015.0      2017.0
# Speed Limit                                  35.0        65.0

# %% [markdown]
# Takeaways
# - Null values are present

# %% [markdown]
# # Prep

# %%
df.head(3)
# Out:
#    Crash ID $1000 Damage to Any One Person's Property Active School Zone Flag  \
# 0  11243623                                        No                      No
# 1  12112069                                        No                      No
# 2  12112069                                        No                      No
#
#   Adjusted Average Daily Traffic Amount                    Agency  \
# 0                                 15262  Austin Police Department
# 1                               No Data  Austin Police Department
# 2                               No Data  Austin Police Department
#
#    At Intersection Flag Average Daily Traffic Amount  \
# 0                 False                        15262
# 1                 False                      No Data
# 2                 False                      No Data
#
#   Average Daily Traffic Year    Case ID    City Construction Zone Flag  \
# 0                       2014  100010723  Austin                     No
# 1                    No Data  100010834  Austin                     No
# 2                    No Data  100010834  Austin                     No
#
#   Construction Zone Workers Present Flag  County  Crash Death Count  \
# 0                                     No  Travis                  0
# 1                                     No  Travis                  0
# 2                                     No  Travis                  0
#
#    Crash Incapacitating Injury Count  Crash Non-incapacitating Injury Count  \
# 0                                  1                                      0
# 1                                  0                                      2
# 2                                  0                                      2
#
#    Crash Not Injured Count  Crash Possible Injury Count  \
# 0                        0                            0
# 1                        1                            0
# 2                        1                            0
#
#               Crash Severity  Crash Time  Crash Total Injury Count  \
# 0      Incapacitating Injury         239                         1
# 1  Non-Incapacitating Injury         310                         2
# 2  Non-Incapacitating Injury         310                         2
#
#    Crash Unknown Injury Count  Crash Year Day of Week First Harmful Event  \
# 0                           1        2010      Friday        Pedalcyclist
# 1                           1        2010      Friday        Pedalcyclist
# 2                           1        2010      Friday        Pedalcyclist
#
#    Highway System Intersecting Street Name Intersection Related     Latitude  \
# 0  Farm To Market                      NaN     Non Intersection  30.28608823
# 1         No Data                      NaN     Non Intersection  30.25524478
# 2         No Data                      NaN     Non Intersection  30.25524478
#
#   Light Condition     Longitude                 Manner of Collision  \
# 0   Dark, Lighted   -97.6805777  One Motor Vehicle - Going Straight
# 1   Dark, Lighted  -97.74505246  One Motor Vehicle - Going Straight
# 2   Dark, Lighted  -97.74505246  One Motor Vehicle - Going Straight
#
#   Number of Lanes    Other Factor Outside Shoulder Width on Divided Highway  \
# 0               4  Not Applicable                                         0
# 1         No Data  Not Applicable                                   No Data
# 2         No Data  Not Applicable                                   No Data
#
#   Physical Feature 1      Population Group Private Drive Flag  \
# 0     Not Applicable  250,000 Pop And Over                 No
# 1     Not Applicable  250,000 Pop And Over                 No
# 2     Not Applicable  250,000 Pop And Over                 No
#
#   Property Damages Right of Way Usual Width      Road Class  \
# 0             NONE                      100  Farm To Market
# 1             NONE                  No Data     City Street
# 2             NONE                  No Data     City Street
#
#      Roadway Alignment      Roadway Part Roadway Relation  \
# 0  Straight, Hillcrest  Main/Proper Lane       On Roadway
# 1      Straight, Level  Main/Proper Lane       On Roadway
# 2      Straight, Level  Main/Proper Lane       On Roadway
#
#                  Roadway Type  Speed Limit     Street Name Street Number  \
# 0  4 Or More Lanes, Undivided           45          FM0969          4716
# 1                     No Data           35  E RIVERSIDE DR           200
# 2                     No Data           35  E RIVERSIDE DR           200
#
#   Surface Condition   Traffic Control Type Weather Condition  Person Helmet  \
# 0               Dry           Marked Lanes             Clear  Worn, Damaged
# 1               Dry  Center Stripe/Divider             Clear       Not Worn
# 2               Dry  Center Stripe/Divider             Clear       Not Worn
#
#     Person Type
# 0  Pedalcyclist
# 1  Pedalcyclist
# 2  Pedalcyclist

# %%
# Drop duplicates
df.drop_duplicates('Crash ID', inplace=True)

# %%
df.drop_duplicates('Case ID', inplace=True)

# %%
for col in ['Case ID', 'Crash ID']:
    print(df[col].isnull().sum())

# %%
df[df['Case ID'].isnull()]

# %%
for col in df.columns:
    df.rename(columns={col:col.replace(" ", "_")}, inplace=True)
df

# %%
x = []
for col in df.columns:
    if df[df[col]=="No Data"].shape[0] > 0:
        x.append(col)

# %%
x

# %%
for col in x:
    print(df[col].value_counts())

# %%
df[df.Property_Damages=='No Data']

# %%
df = df[(df.Longitude!='No Data') | (df.Latitude!='No Data')]

# %%
df.isnull().sum()

# %%
def plot_dist(quant_vars, cat_vars):
    '''
    Function loops through all columns and plot each distribution.
    '''
    for col in df.drop(columns=['Longitude', 'Latitude']).columns:
        plt.title(f'Histogram for {col}')
        sns.histplot(x=df[col], hue=df['Crash_Severity'], bins=10)
        plt.tight_layout()
        plt.show()

# %%
for col in df.drop(columns=['Crash_Severity', 'Case_ID', 'Crash_ID']).columns:
    sns.histplot(x=df[col], hue=df['Crash_Severity'])

# %%
plot_dist(quant_vars, cat_vars)

# %%
df.drop(columns=['Intersecting_Street_Name', 
                 'Case_ID', 
                 'Crash_ID', 
                 'Active_School_Zone_Flag', 
                 'City', 
                 'County', 
                 'Population_Group', 
                 'Private_Drive_Flag', 
                 'Person_Type',
                 'Agency', 
                 'Street_Name',
                 'Street_Number', 
                 'Other_Factor',
                 'First_Harmful_Event',
                 'Physical_Feature_1', 
                 'Crash_Death_Count',
                 'Crash_Incapacitating_Injury_Count',
                 'Crash_Non-incapacitating_Injury_Count', 
                 'Crash_Not_Injured_Count',
                 'Crash_Possible_Injury_Count', 
                 'Traffic_Control_Type']
        , inplace=True)

# %%
df.head(3)

# %%
df.rename(columns={"$1000_Damage_to_Any_One_Person's_Property" : "one-k_prop_dmg",
                   "At_Intersection_Flag": "at_inter",
                   "Construction_Zone_Flag": "con_zone",
                   "Construction_Zone_Workers_Present_Flag": "con_workers_pres",
                   "Crash_Possible_Injury_Count": "poss_injured_count", 
                   "Crash_Time": "time", 
                   "Crash_Total_Injury_Count": "total_injured",
                   "Crash_Unknown_Injury_Count": 'unknown_inj_count',
                   "Crash_Year": "year",
                   "Day_of_Week": "day",
                   "Intersection_Related": "inter_related",
                   "Light_Condition": "light_condition",
                   "Manner_of_Collision": "coll_type",
                  }, inplace=True)

# %%
for col in df.columns:
    print(df[col].value_counts())
    print()

# %%
dummy_df = pd.get_dummies(df[["day",
                              "inter_related",
                              "light_condition",
                              "coll_type",
                              "Road_Class",
                              "Roadway_Alignment",
                              "Roadway_Part",
                              "Roadway_Relation",
                              "Surface_Condition",
                              "Weather_Condition",
                              "Person_Helmet",
                             ]], dummy_na=False, drop_first=False)
dummy_df.head()

# %%
df = pd.concat([df.drop(columns=["day",
                              "inter_related",
                              "light_condition",
                              "coll_type",
                              "Road_Class",
                              "Roadway_Alignment",
                              "Roadway_Part",
                              "Roadway_Relation",
                              "Surface_Condition",
                              "Weather_Condition",
                              "Person_Helmet",
                             ]), dummy_df], axis=1)

# %%
df.replace({'one-k_prop_dmg': {'No': 0, 'Yes': 1},
            'at_inter': {False: 0, True: 1},
            'con_zone': {'No': 0, 'Yes': 1},
            'con_workers_pres': {'No': 0, 'Yes': 1}
           }, inplace=True)

# %%
df.head(3)

# %%
plt.figure(figsize=(15,6))
sns.histplot(df.Crash_Severity)

# %%
df.replace({'Crash Severity': {'Non-Incapacitating Injury': 0, 
                               'Possible Injury': 0, 
                               'Not Injured': 0,
                               'Incapacitating Injury': 1,
                               'Killed': 1},
            }, inplace=True)

# %%
df = df[df['Crash Severity'] != 'Unknown']

# %%
df = df.reset_index()
df = df.drop(columns='index')

# %%
df

# %%
def train_validate_test_split(df, target, seed=123):
    '''
    This function takes in a dataframe, the name of the target variable
    (for stratification purposes), and an integer for a setting a seed
    and splits the data into train, validate and test. 
    Test is 20% of the original dataset, validate is .30*.80= 24% of the 
    original dataset, and train is .70*.80= 56% of the original dataset. 
    The function returns, in this order, train, validate and test dataframes. 
    '''
    train_validate, test = train_test_split(df, test_size=0.2, 
                                            random_state=seed, 
                                            stratify=df[target])
    train, validate = train_test_split(train_validate, test_size=0.3, 
                                       random_state=seed,
                                       stratify=train_validate[target])
    return train, validate, test
train, validate, test = train_validate_test_split(df, 'Crash_Severity', seed=123)

# %%
print(f'train -> {train.shape}')
print(f'validate -> {validate.shape}')
print(f'test -> {test.shape}')

# %%
train

# %%
def explore_univariate(train, cat_vars, quant_vars):
    for var in cat_vars:
        explore_univariate_categorical(train, var)
        print('_________________________________________________________________')
    for col in quant_vars:
        p, descriptive_stats = explore_univariate_quant(train, col)
        plt.show(p)
        print(descriptive_stats)

def explore_bivariate(train, target, cat_vars, quant_vars):
    for cat in cat_vars:
        explore_bivariate_categorical(train, target, cat)
    for quant in quant_vars:
        explore_bivariate_quant(train, target, quant)

def explore_multivariate(train, target, cat_vars, quant_vars):
    '''
    '''
    plot_swarm_grid_with_color(train, target, cat_vars, quant_vars)
    plt.show()
    violin = plot_violin_grid_with_color(train, target, cat_vars, quant_vars)
    plt.show()
    pair = sns.pairplot(data=train, vars=quant_vars, hue=target)
    plt.show()
    plot_all_continuous_vars(train, target, quant_vars)
    plt.show()    


### Univariate

def explore_univariate_categorical(train, cat_var):
    '''
    takes in a dataframe and a categorical variable and returns
    a frequency table and barplot of the frequencies. 
    '''
    frequency_table = freq_table(train, cat_var)
    plt.figure(figsize=(2,2))
    sns.barplot(x=cat_var, y='Count', data=frequency_table, color='lightseagreen')
    plt.title(cat_var)
    plt.show()
    print(frequency_table)

def explore_univariate_quant(train, quant_var):
    '''
    takes in a dataframe and a quantitative variable and returns
    descriptive stats table, histogram, and boxplot of the distributions. 
    '''
    descriptive_stats = train[quant_var].describe()
    plt.figure(figsize=(8,2))

    p = plt.subplot(1, 2, 1)
    p = plt.hist(train[quant_var], color='lightseagreen')
    p = plt.title(quant_var)

    # second plot: box plot
    p = plt.subplot(1, 2, 2)
    p = plt.boxplot(train[quant_var])
    p = plt.title(quant_var)
    return p, descriptive_stats

def freq_table(train, cat_var):
    '''
    for a given categorical variable, compute the frequency count and percent split
    and return a dataframe of those values along with the different classes. 
    '''
    class_labels = list(train[cat_var].unique())

    frequency_table = (
        pd.DataFrame({cat_var: class_labels,
                      'Count': train[cat_var].value_counts(normalize=False), 
                      'Percent': round(train[cat_var].value_counts(normalize=True)*100,2)}
                    )
    )
    return frequency_table


#### Bivariate

def explore_bivariate_categorical(train, target, cat_var):
    '''
    takes in categorical variable and binary target variable, 
    returns a crosstab of frequencies
    runs a chi-square test for the proportions
    and creates a barplot, adding a horizontal line of the overall rate of the target. 
    '''
    print(cat_var, "\n_____________________\n")
    ct = pd.crosstab(train[cat_var], train[target], margins=True)
    chi2_summary, observed, expected = run_chi2(train, cat_var, target)
    p = plot_cat_by_target(train, target, cat_var)

    print(chi2_summary)
    print("\nobserved:\n", ct)
    print("\nexpected:\n", expected)
    plt.show(p)
    print("\n_____________________\n")

def explore_bivariate_quant(train, target, quant_var):
    '''
    descriptive stats by each target class. 
    compare means across 2 target groups 
    boxenplot of target x quant
    swarmplot of target x quant
    '''
    print(quant_var, "\n____________________\n")
    descriptive_stats = train.groupby(target)[quant_var].describe()
    average = train[quant_var].mean()
    mann_whitney = compare_means(train, target, quant_var)
    plt.figure(figsize=(4,4))
    boxen = plot_boxen(train, target, quant_var)
    swarm = plot_swarm(train, target, quant_var)
    plt.show()
    print(descriptive_stats, "\n")
    print("\nMann-Whitney Test:\n", mann_whitney)
    print("\n____________________\n")
    
## Bivariate Categorical

def run_chi2(train, cat_var, target):
    observed = pd.crosstab(train[cat_var], train[target])
    chi2, p, degf, expected = stats.chi2_contingency(observed)
    chi2_summary = pd.DataFrame({'chi2': [chi2], 'p-value': [p], 
                                 'degrees of freedom': [degf]})
    expected = pd.DataFrame(expected)
    return chi2_summary, observed, expected

def plot_cat_by_target(train, target, cat_var):
    p = plt.figure(figsize=(2,2))
    p = sns.barplot(cat_var, target, data=train, alpha=.8, color='lightseagreen')
    overall_rate = train[target].mean()
    p = plt.axhline(overall_rate, ls='--', color='gray')
    return p


## Bivariate Quant

def plot_swarm(train, target, quant_var):
    average = train[quant_var].mean()
    p = sns.swarmplot(data=train, x=target, y=quant_var, color='lightgray')
    p = plt.title(quant_var)
    p = plt.axhline(average, ls='--', color='black')
    return p

def plot_boxen(train, target, quant_var):
    average = train[quant_var].mean()
    p = sns.boxenplot(data=train, x=target, y=quant_var, color='lightseagreen')
    p = plt.title(quant_var)
    p = plt.axhline(average, ls='--', color='black')
    return p

# alt_hyp = ‘two-sided’, ‘less’, ‘greater’

def compare_means(train, target, quant_var, alt_hyp='two-sided'):
    x = train[train[target]==0][quant_var]
    y = train[train[target]==1][quant_var]
    return stats.mannwhitneyu(x, y, use_continuity=True, alternative=alt_hyp)


### Multivariate

def plot_all_continuous_vars(train, target, quant_vars):
    '''
    Melt the dataset to "long-form" representation
    boxenplot of measurement x value with color representing the target variable. 
    '''
    my_vars = [item for sublist in [quant_vars, [target]] for item in sublist]
    sns.set(style="whitegrid", palette="muted")
    melt = train[my_vars].melt(id_vars=target, var_name="measurement")
    plt.figure(figsize=(8,6))
    p = sns.boxenplot(x="measurement", y="value", hue=target, data=melt)
    p.set(yscale="log", xlabel='')    
    plt.show()

def plot_violin_grid_with_color(train, target, cat_vars, quant_vars):
    cols = len(cat_vars)
    for quant in quant_vars:
        _, ax = plt.subplots(nrows=1, ncols=cols, figsize=(16, 4), sharey=True)
        for i, cat in enumerate(cat_vars):
            sns.violinplot(x=cat, y=quant, data=train, split=True, 
                           ax=ax[i], hue=target, palette="Set2")
            ax[i].set_xlabel('')
            ax[i].set_ylabel(quant)
            ax[i].set_title(cat)
        plt.show()

def plot_swarm_grid_with_color(train, target, cat_vars, quant_vars):
    cols = len(cat_vars)
    for quant in quant_vars:
        _, ax = plt.subplots(nrows=1, ncols=cols, figsize=(16, 4), sharey=True)
        for i, cat in enumerate(cat_vars):
            sns.swarmplot(x=cat, y=quant, data=train, ax=ax[i], hue=target, palette="Set2")
            ax[i].set_xlabel('')
            ax[i].set_ylabel(quant)
            ax[i].set_title(cat)
        plt.show()

# %%
for col in df.columns:
    print(col, df[col].nunique())

# %%
explore_univariate(train, cat_vars, quant_vars)

# %% [markdown]
# Takeaways:
# - Speed limit may be a factor
# - Light condition looks like a factor
# - Most happen on city streets
# - straight and level roads
# - riding on the road
# - Dry conditions
# - clear weather
# - helmets!

# %% [markdown]
# # Exploration

# %% [markdown]
# Let's check out some of the prepare takeaways

# %% [markdown]
# sns.histplot(x=train.Speed_Limit, hue=train.Crash_Severity)

# %% [markdown]
# for col in df.columns:
#     print(df[df['Speed Limit']<=10][col].value_counts())

# %% [markdown]
# In [5]:
# def plot_dist(quant_vars, cat_vars):
#     '''
#     Function loops through all columns and plot each distribution.
#     '''
#     for col in df.columns[1:]:
#         plt.title(f'Histogram for {col}')
#         sns.histplot(x=df[col], hue=df.churn, bins=10)
#         plt.tight_layout()
#         plt.show()
